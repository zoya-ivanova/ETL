# %% [markdown]
# <a href="https://colab.research.google.com/github/zoya-ivanova/ETL/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ETL: автоматизация подготовки данных
# ### Модели данных и нормализация таблиц. Схема «звезда»
#
# ####1. Нарисуйте архитектуру ETL процесса (извлечение, трансформация и загрузка данных) для сбора и анализа данных компанией которая хочет провести маркетинговую кампанию, используя app.diagrams.net. Сделайте описание почему вы считаете что архитектура должна выглядеть именно так.<br> ![Архитектура сбора данных.png](data:image/png;base64,...)

# %% [markdown]
# 1. Источники данных:
# - CRM система компании для получения информации о клиентах, покупках и других взаимодействиях.
# - Социальные медиа платформы для анализа поведения пользователей и реакции на рекламные кампании.
# - Веб-сайт компании для сбора информации о посетителях и их действиях.
# - Внешние источники данных для получения дополнительной информации о целевой аудитории.
#
#   Извлечение данных:
# - Извлечение данных из источников с помощью API, ETL инструментов или скриптов.
# - Фильтрация и очистка данных для удаления дубликатов, ошибок и недостоверной информации.
#
# 2. Трансформация данных:
# - Преобразование данных в удобный для анализа формат.
# - Объединение данных из различных источников для создания единой базы данных.
# - Расширение данных с помощью внешних источников для получения дополнительной информации.
#
# 3. Загрузка данных:
# - Загрузка данных в хранилище данных с помощью ETL инструментов или баз данных.
# - Создание отчетов и дашбордов для визуализации данных и мониторинга результатов маркетинговой кампании.
#
# Таким образом, архитектура ETL процесса для сбора и анализа данных в маркетинговой кампании может быть представлена в виде цепочки шагов, начиная с извлечения данных из источников и заканчивая загрузкой данных в хранилище данных и созданием отчетов и дашбордов для анализа результатов.

# %% [markdown]
# ####2. Постройте реляционную и иерархическую модели данных для магазина который продает телефоны.

# %% [markdown]
# Иерархическая модель:<br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Реляционная модель:<br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####3. Определите в какой нормальной форме данная таблица, приведите её ко 2 и 3 нормальным формам последовательно:

# %% [markdown]
# Данная таблица в первой нормальной форме:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Приводим таблицу ко второй нормальной форме (2НФ):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Приводим таблицу к третьей нормальной форме (3НФ):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
